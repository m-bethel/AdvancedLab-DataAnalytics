# %%
from pdf2image import convert_from_path
from IPython.display import display
images = convert_from_path(r"C:\Users\miles\BYU-Idaho\11th Semester\336 Advanced Lab\TESTS\Test3-Final\336-test-final-Wi-26.pdf")
for img in images:
    display(img)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200>

# %% [markdown]
# ## Problem 1.

# %%
from pdf2image import convert_from_path
from IPython.display import display
images = convert_from_path(r"C:\Users\miles\BYU-Idaho\11th Semester\336 Advanced Lab\TESTS\Test3-Final\Problem 1 Mathematica.pdf")
for img in images:
    display(img)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200>

# %% [markdown]
# Value for z: -1.4 +- 0.4

# %% [markdown]
# ## Problem 2.

# %% [markdown]
# a) Determine an expected relationship for $ s(m) $
# $$\Large{s = \sqrt[3]{ \frac{m}{\rho}} }$$

# %%
import numpy as np
from scipy.optimize import curve_fit

m = np.array([4.5,6.0,7.5,9.0,12.0,15.0,18.0])
s = np.array([1.07,1.14,1.24,1.32,1.41,1.57,1.65])


def f(m,s):
    return m/(s*s*s) 
    
fit, err =curve_fit(f,s,m, p0 = [initialguess])

p = fit

dp = np.sqrt(np.diag(err))

print(dp)
# Out:
# [ 45.22279243 183.85331125 246.40644641 108.87145812]
